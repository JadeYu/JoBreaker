# %%
import pandas as pd
import numpy as np
from sklearn.cross_validation import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import joblib

#my own functions cleaning raw text
import preprocessing as pps
import getkeywords as gkw
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#read in data
df = pd.read_csv("../../data/All_Data.csv", index_col=0)
df.shape
# Out:
# (1984, 8)

# %%
#write data distribution across states to a csv file
pd.DataFrame(df['state'].value_counts()).to_csv("../metrics/state_distribution.csv")

# %%
#filter data (get rid of the jobtitles that do not go into the model)
df = df[df["jobtitle"] != 'Machine Learning']
df = df[df["jobtitle"] != 'Data Architect']
df = df[df["jobtitle"] != 'Data Analyst']
#df = df[df["jobtitle"] != 'Data Engineer']
df.shape
# Out:
# (1507, 8)

# %%
#look at the jobtitles left
set(df['jobtitle'])
# Out:
# {'Business Analyst',
#  'Data Engineer',
#  'Data Scientist',
#  'Database Administrator',
#  'Product Manager'}

# %%
#split and preprocess data
data_train, data_test = pps.kfold_split(df, k=5)
train_feature = pps.raw_cleaning(data_train['snippet'], False)
train_labels = data_train['jobtitle']

# %%
#build pipeline including a transformer and a classifier
text_clf = Pipeline([('vect', TfidfVectorizer(max_df = 0.99, min_df = 0.01,ngram_range=(1,2))),
                     ('clf', RandomForestClassifier(n_estimators=200)),
])
text_clf = text_clf.fit(train_feature, train_labels)

# %%
#see how the pipeline performs on test data
test_feature = pps.raw_cleaning(data_test['snippet'], False)
predicted = text_clf.predict(test_feature)
test_labels = data_test['jobtitle']
#output = pd.DataFrame(predicted, test_labels)
print(np.mean(predicted == test_labels)) 
#print(output)
confusion = pd.DataFrame(confusion_matrix(predicted, test_labels, labels=list(set(test_labels))), columns = list(set(test_labels)))
confusion = confusion.div(confusion.sum(axis=0), axis=1)
f1s = metrics.classification_report(test_labels, predicted)
# Out:
# 0.75415282392

# %%
print(f1s)
# Out:
#                         precision    recall  f1-score   support
#
#       Business Analyst       0.76      0.88      0.82        83
#          Data Engineer       0.75      0.37      0.49        41
#         Data Scientist       0.79      0.74      0.76        57
# Database Administrator       0.71      0.73      0.72        55
#        Product Manager       0.75      0.88      0.81        65
#
#            avg / total       0.75      0.75      0.74       301

# %%
confusion
# Out:
#    Data Scientist  Database Administrator  Product Manager  Business Analyst  \
# 0        0.736842                0.036364         0.000000          0.036145
# 1        0.035088                0.727273         0.015385          0.036145
# 2        0.122807                0.054545         0.876923          0.048193
# 3        0.035088                0.163636         0.107692          0.879518
# 4        0.070175                0.018182         0.000000          0.000000
#
#    Data Engineer
# 0       0.146341
# 1       0.243902
# 2       0.121951
# 3       0.121951
# 4       0.365854

# %%
#write the confusion matrix to a csv file
#confusion.to_csv("../metrics/confusion_matrix_all.csv")
#dump the pipeline object to the target directory
joblib.dump(text_clf, "../JB_app/models/text_clf_medium.pkl")
# Out:
# ['../JB_app/models/text_clf_medium.pkl']

# %%
#test on one entry
new_data = [data_test['snippet'].iloc[1]]
new_feature = pps.raw_cleaning(new_data, False)
prediction = text_clf.predict_proba(new_feature)
output = pd.DataFrame()
output['jobtitle'] = text_clf.classes_
output['probability'] = prediction[0]
output = output.sort_values(by='probability', ascending=False)
output
# Out:
#                  jobtitle  probability
# 2          Data Scientist      0.69125
# 1           Data Engineer      0.13875
# 0        Business Analyst      0.10500
# 3  Database Administrator      0.03500
# 4         Product Manager      0.03000

# %%
#calculate a document * label table with each element being the probability of a document being a label
likelihoods = pd.DataFrame(columns = list(set(df['jobtitle'])))
for i in range(df.shape[0]):
    new = [df['snippet'].iloc[i]]
    feature = pps.raw_cleaning(new, False)
    prediction = text_clf.predict_proba(feature)[0]
    labels = text_clf.classes_
    likelihoods = likelihoods.append(pd.Series({label:ll for label, ll in zip(labels, prediction)}, name = str(i)))
likelihoods.head()
# Out:
#    Business Analyst  Data Scientist  Product Manager  Database Administrator  \
# 0             0.085           0.665            0.165                   0.035
# 1             0.025           0.880            0.035                   0.010
# 2             0.060           0.810            0.030                   0.015
# 3             0.170           0.720            0.055                   0.030
# 4             0.000           0.005            0.025                   0.010
#
#    Data Engineer
# 0          0.050
# 1          0.050
# 2          0.085
# 3          0.025
# 4          0.960

# %%
likelihoods.to_csv("../metrics/likelihoods_table_medium.csv")

# %%
ll_table = pd.read_csv("../metrics/likelihoods_table_medium.csv", index_col=0)
ll_table.head()
# Out:
#    Business Analyst  Data Scientist  Product Manager  Database Administrator  \
# 0             0.085           0.665            0.165                   0.035
# 1             0.025           0.880            0.035                   0.010
# 2             0.060           0.810            0.030                   0.015
# 3             0.170           0.720            0.055                   0.030
# 4             0.000           0.005            0.025                   0.010
#
#    Data Engineer
# 0          0.050
# 1          0.050
# 2          0.085
# 3          0.025
# 4          0.960

# %%
prototypes = gkw.get_prototypes(ll_table)
prototypes
# Out:
# {'Business Analyst': [1179,
#   1181,
#   1412,
#   1343,
#   1103,
#   639,
#   1374,
#   1445,
#   810,
#   1503],
#  'Data Engineer': [337, 336, 588, 586, 584, 73, 713, 80, 334, 709],
#  'Data Scientist': [412, 414, 773, 1429, 1014, 1426, 1427, 580, 326, 138],
#  'Database Administrator': [614, 613, 408, 404, 1404, 957, 961, 745, 673, 178],
#  'Product Manager': [1219, 1335, 248, 24, 159, 163, 399, 1390, 521, 1467]}

# %%
tfs = pd.read_csv("../metrics/All_tfidf_features_99.csv", index_col=0)
tfs.head()
# Out:
#     company        jobtitle  \
# 21      0.0  Data Scientist
# 36      0.0  Data Scientist
# 39      0.0  Data Scientist
# 40      0.0  Data Scientist
# 48      0.0   Data Engineer
#
#                                         jobtitle_orig  ability  \
# 21                              Data Scientist - Risk      0.0
# 36                        Data Scientist - Operations      0.0
# 39                                     Data Scientist      0.0
# 40                                     Data Scientist      0.0
# 48  Data Engineer – Information Management & Analy...      0.0
#
#     ability develop  ability work  able    access  account  accounting  \
# 21              0.0           0.0   0.0  0.000000      0.0         0.0
# 36              0.0           0.0   0.0  0.000000      0.0         0.0
# 39              0.0           0.0   0.0  0.253007      0.0         0.0
# 40              0.0           0.0   0.0  0.000000      0.0         0.0
# 48              0.0           0.0   0.0  0.000000      0.0         0.0
#
#         ...        work experience  workflow  working     world  writing  \
# 21      ...                    0.0       0.0      0.0  0.000000      0.0
# 36      ...                    0.0       0.0      0.0  0.000000      0.0
# 39      ...                    0.0       0.0      0.0  0.232879      0.0
# 40      ...                    0.0       0.0      0.0  0.000000      0.0
# 48      ...                    0.0       0.0      0.0  0.000000      0.0
#
#     written      year  year experience  year related  year relevant
# 21      0.0  0.000000              0.0           0.0            0.0
# 36      0.0  0.109386              0.0           0.0            0.0
# 39      0.0  0.000000              0.0           0.0            0.0
# 40      0.0  0.000000              0.0           0.0            0.0
# 48      0.0  0.000000              0.0           0.0            0.0
#
# [5 rows x 774 columns]

# %%
result = {}
features = tfs.iloc[:,3:]
words = list(features.columns)
label = 'Data Scientist'
tmp = pd.DataFrame()
tmp['words'] = words
tmp['tfidf'] = list(features.iloc[prototypes[label],:].sum(axis=0))
tmp = tmp.sort_values(by = 'tfidf', ascending = False)
tmp['words'].iloc[:20]
# Out:
# 660                statistic
# 437              mathematics
# 32                 analytics
# 482       operation research
# 615                  science
# 622        science statistic
# 661    statistic mathematics
# 448                   method
# 259              engineering
# 135         computer science
# 438     mathematics computer
# 133                 computer
# 109                 clinical
# 434            master degree
# 582            related field
# 481                operation
# 597                 research
# 579                  related
# 433                   master
# 286               experience
# Name: words, dtype: object

# %%
keywords = gkw.get_keywords(tfs.iloc[:,3:], prototypes, 100)

# %%
keywords.iloc[:20,:]
# Out:
#            Data Scientist         Data Engineer  Product Manager  \
# 0               statistic                  data          product
# 1             mathematics   university computer         strategy
# 2               analytics                  kpmg           market
# 3      operation research         pipeline data             sale
# 4                 science                 azure          manager
# 5       science statistic                   aws             plan
# 6   statistic mathematics                 stack          develop
# 7                  method       data processing          revenue
# 8             engineering     degree accredited     team develop
# 9        computer science              pipeline          pricing
# 10   mathematics computer               setting           target
# 11               computer    accredited college        lifecycle
# 12               clinical    college university        strategic
# 13          master degree           data mining  product manager
# 14          related field      science computer              new
# 15              operation  computer engineering      responsible
# 16               research               variety       life cycle
# 17                related                mining          roadmap
# 18                 master              computer            cycle
# 19             experience            university      new product
#
#      Business Analyst  Database Administrator
# 0            business                database
# 1             analyst                     sql
# 2         requirement          implementation
# 3    business analyst               procedure
# 4              system                     dba
# 5     business system                 support
# 6            analysis         backup recovery
# 7              design                 creates
# 8          experience  database administrator
# 9                need              production
# 10           solution                  design
# 11            diagram               architect
# 12            process           administrator
# 13           document                recovery
# 14      business need                  assist
# 15  business analysis                  backup
# 16              state   design implementation
# 17            current         database design
# 18               year                software
# 19         technology                hardware

# %%
keywords.to_csv("../JB_app/keywords_medium_100.csv")

# %%
keywords = pd.read_csv("../JB_app/keywords_medium_100.csv", index_col=0)
keywords
# Out:
#             Data Scientist         Data Engineer             Product Manager  \
# 0                statistic                  data                     product
# 1              mathematics   university computer                    strategy
# 2                analytics                  kpmg                      market
# 3       operation research         pipeline data                        sale
# 4                  science                 azure                     manager
# 5        science statistic                   aws                        plan
# 6    statistic mathematics                 stack                     develop
# 7                   method       data processing                     revenue
# 8              engineering     degree accredited                team develop
# 9         computer science              pipeline                     pricing
# 10    mathematics computer               setting                      target
# 11                computer    accredited college                   lifecycle
# 12                clinical    college university                   strategic
# 13           master degree           data mining             product manager
# 14           related field      science computer                         new
# 15               operation  computer engineering                 responsible
# 16                research               variety                  life cycle
# 17                 related                mining                     roadmap
# 18                  master              computer                       cycle
# 19              experience            university                 new product
# 20               personnel            accredited                        team
# 21                   field            technology              responsibility
# 22             statistical             algorithm                        life
# 23        machine learning               college                 opportunity
# 24                 machine            processing  development implementation
# 25                analytic               science                    includes
# 26                learning   engineering related                      enable
# 27    statistical analysis                client                 develop new
# 28            optimization          data science                  developing
# 29                two year                  test                      growth
# ..                     ...                   ...                         ...
# 70              developing             personnel           develop implement
# 71                 minimum                 phase                   portfolio
# 72                question                   phd            cross functional
# 73              understand             portfolio                  enterprise
# 74                   large                physic                  commercial
# 75             responsible                policy                     focused
# 76                relevant              physical                   education
# 77                modeling                  plus                       multi
# 78                 working                  plan                     execute
# 79         year experience              planning                        line
# 80             information            predictive                        meet
# 81               technical               ability                     include
# 82                    tool            preferably                    activity
# 83              structured             providing                 engineering
# 84      related experience               project                work closely
# 85                   power    project management                         key
# 86                material             protected            product strategy
# 87  electrical engineering             prototype                       class
# 88               answering                proven                        well
# 89         experience data               provide                       world
# 90        strong technical     provide technical                 collaborate
# 91                      bi              provides                     deliver
# 92                   least                python                     working
# 93             effectively           proficiency                  functional
# 94             large scale                    qa                     driving
# 95              electrical             qualified                     partner
# 96             data driven               quality                   implement
# 97                    hand          quantitative                  technology
# 98   mathematics statistic    quantitative field                     process
# 99                  result                 query                        year
#
#        Business Analyst   Database Administrator
# 0              business                 database
# 1               analyst                      sql
# 2           requirement           implementation
# 3      business analyst                procedure
# 4                system                      dba
# 5       business system                  support
# 6              analysis          backup recovery
# 7                design                  creates
# 8            experience   database administrator
# 9                  need               production
# 10             solution                   design
# 11              diagram                architect
# 12              process            administrator
# 13             document                 recovery
# 14        business need                   assist
# 15    business analysis                   backup
# 16                state    design implementation
# 17              current          database design
# 18                 year                 software
# 19           technology                 hardware
# 20               global              application
# 21              support                 provides
# 22            technical                      day
# 23                 rule                  upgrade
# 24  experience business                  monitor
# 25                field              performance
# 26            interface                   system
# 27          forecasting                     high
# 28                using                microsoft
# 29                 user               sql server
# ..                  ...                      ...
# 70                 data               equivalent
# 71  relevant experience                knowledge
# 72        year relevant                 customer
# 73                 step                technical
# 74              creates                 activity
# 75               gather              information
# 76              develop               experience
# 77              present                     wide
# 78            associate               technology
# 79           consistent                   vendor
# 80               script            related field
# 81         minimum year                     data
# 82               driver             installation
# 83       recommendation              maintaining
# 84           life cycle                  package
# 85    technical product      technical expertise
# 86           accounting                     work
# 87             directly           responsibility
# 88         future state               high level
# 89                 unit                  general
# 90            corporate     software development
# 91      field preferred         computer science
# 92             workflow               supporting
# 93                cycle  database administration
# 94              end end                 computer
# 95          appropriate               coordinate
# 96           efficiency                  related
# 97             function             implementing
# 98          identifying                  project
# 99             approach                    field
#
# [100 rows x 5 columns]

# %%
gkw.common_keywords('Data Engineer','Data Scientist',keywords)
# Out:
# ['data',
#  'university computer',
#  'azure',
#  'accredited college',
#  'college university',
#  'data mining',
#  'mining',
#  'computer',
#  'university',
#  'accredited',
#  'algorithm',
#  'college',
#  'science',
#  'engineering related',
#  'engineering',
#  'field minimum',
#  'related field',
#  'year',
#  'minimum',
#  'computer science',
#  'related',
#  'two year',
#  'field',
#  'two',
#  'degree',
#  'experience',
#  'year experience',
#  'power',
#  'personnel',
#  'phd',
#  'physic',
#  'ability']

# %%
new = [df['snippet'].iloc[3]]
cleaned_text = pps.raw_cleaning(new, False)
cleaned_grams = get_grams(new, False)
gkw.contributing_words(cleaned_grams, keywords)
# Out:
# {'Business Analyst': 'analysis, design, experience, perform, required',
#  'Data Engineer': 'experience, perform, plan, power, provide',
#  'Data Scientist': 'analysis, clinical, design, experience, power, statistical',
#  'Database Administrator': 'assist, design, experience, plan',
#  'Product Manager': 'experience, plan'}
